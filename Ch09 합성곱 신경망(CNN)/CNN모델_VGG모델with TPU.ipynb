# %% [markdown]
# # TPU

# %%
# TPU 초기화 하기
import tensorflow as tf
import os

resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])

tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4508\3548141448.py in <module>
#       3 import os
#       4
# ----> 5 resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])
#       6
#       7 tf.config.experimental_connect_to_cluster(resolver)
#
# c:\ProgramData\Anaconda3\lib\os.py in __getitem__(self, key)
#     677         except KeyError:
#     678             # raise KeyError with the original key value
# --> 679             raise KeyError(key) from None
#     680         return self.decodevalue(value)
#     681
#
# KeyError: 'COLAB_TPU_ADDR'

# %%
# TPU strategy(분산 처리 전략)세팅
# tf.distribute.Strategy는 모델, 훈련 코드를 분산처리로 할 수 있게 해준다.
strategy = tf.distribute.TPUStrategy(resolver)

# %%
#모델 컴파일 할 때는 with stragegy.scope(): 다음에 들여쓰기 하고, create_model() 함수를 
# 호출하는 식으로 모델 컴파일 한다. 곧,strategy.scope 내에서 모델을 컴파일 한다

# %% [markdown]
# # 사전학습 모델

# %% [markdown]
# # VGG 모델
# - CNN을 쓰는 모델 중 하나
# - VGG16, 19가 있음 => 합성곱 층과 완전 연결층의 숫자가 16, 19인 모델(드롭아웃 같은 층은 제외)
# - 입력 데이터 사이즈는 224 * 224, RGB 3개 채널을 인풋으로 받음

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications.imagenet_utils import preprocess_input
# preprocess_input 
# 데이터 전처리를 위한 함수, RGB 순서의 이미지를 BGR 순서로 바꿔준다.
# VGG모델 개발할 때 이런 전처리가 있으니까 결과가 잘 나왔다.

#1: RGB
# cifar10데이터 셋을 로드했음
# 총 클래스 10개로 구성되어 있는 데이터 셋이다.
# 이 이미지들을 분류할 것이다!
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')

#2: default mode 'caffe' style
# 데이터 전처리, BGR로 바꿈
X = x_train.copy()
Y1 = preprocess_input(X)
del X # 메모리 삭제

# #5: display image
fig, ax = plt.subplot(1, 2, figsize=(10,6))
ax[0].imshow(x_train[0,:,:,:].astype(np.unit8))
ax[0].set_title("x_train[0]:RGB")
ax[0].axis("off")

mean = np.array([103.939, 116.779, 123.68], dtype=np.float32)
Y1 += mean
ax[1].imshow(Y1[0,:,:,:].astype(np.unit8))
ax[1].set_title("Y1[0]:RGB")
ax[1].axis("off")
fig.tight_layout()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 213s 1us/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions #preprocess_input 데이터(이미지) 전처리를 위한 함수
from tensorflow.keras.preprocessing import image
from keras.utils import load_img
from keras.utils import img_to_array
from keras.utils import array_to_img

#2 
model = VGG16(weights='imagenet', include_top=True)
model.summary()

#3 predict an image
img_path = './San.png'
img = load_img(img_path, target_size = (224, 224))
x = img_to_array(img) # 배열 변환
x = np.expand_dims(x, axis=0) # 배치 축을 추가
x = preprocess_input(x) # RGB순을 BGR순으로 전처리
output = model.predict(x) 

#3-1
print('Predicted:', decode_predictions(output, top=5)[0]) # 가장 확률이 높은 5개 출력

#4
plt.imshow(img)
plt.axis("off")
plt.show(0)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 [==============================] - 62s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4508\994219707.py in <module>
#      14 #3 predict an image
#      15 img_path = './San.png'
# ---> 16 img = load_img(img_path, target_size = (224, 224))
#      17 x = img_to_array(img) # 배열 변환
#      18 x = np.expand_dims(x, axis=0) # 배치 축을 추가
#
# ~\AppData\Roaming\Python\Python39\site-packages\keras\utils\image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420         if isinstance(path, pathlib.Path):
#     421             path = str(path.resolve())
# --> 422         with open(path, "rb") as f:
#     423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: './San.png'

# %%
def create_model():
  return tf.keras.Sequential(
      [tf.keras.layers.Conv2D(256, 3, activation='relu', input_shape=(28,28,1)),
       tf.keras.layers.Conv2D(256, 3, activation='relu'),
       tf.keras.layers.Flatten(),
       tf.keras.layers.Dense(256, activation='relu'),
       tf.keras.layers.Dense(128, activation='relu'),
       tf.keras.layers.Dense(10)]
  )

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
from keras.utils import load_img
from keras.utils import img_to_array
from keras.utils import array_to_img
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications.vgg16 import preprocess_input, VGG16
import matplotlib.pyplot as plt

# %%
## TPU환경 아래에서 실행한다.
with strategy.scope():
  model = create_model()
  model.compile(optimizer = 'adam',
                loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['sparse_categorical_accuracy'])
    
  (x_train, y_train), (x_test, y_test) = cifar10.load_data() # 데이터로드
  x_train = x_train.astype('float32')
  x_test = x_test.astype('float32')

  # one-hot
  y_train = tf.keras.utils.to_categorical(y_train)
  y_test = preprocess_input(x_test)

  #4 include_top= False로 줘야 학습데이터가 들어옴
  # include_top= True로 주면 분류를 위한 완전연결층을 포함한다.
  model = VGG16(weights=None, include_top = True, classes = 10, input_shape=(32,32,3))
  model. summary(0)

  #5 
  opt = tf.keras.optimizers.RMSprop(learning_rate=0.001)
  model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
  ret = model.fit(x_train, y_train, epochs=100, batch_size=400,
                  validation_split=0.2, verbose=1)
  train_loss, train_acc = model.evaluate(x_train, y_train, verbose=1)
  test_loss, test_acc = model.evaluate(x_test, y_test, verbose=1)
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  fc1 (Dense)                 (None, 4096)              2101248
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 10)                40970
#
# =================================================================
# Total params: 33,638,218
# Trainable params: 33,638,218
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 100/100 [==============================] - 22s 73ms/step - loss: 7218.2412 - accuracy: 0.1016 - val_loss: 2.3030 - val_accuracy: 0.0980
# Epoch 2/100
# 100/100 [==============================] - 4s 42ms/step - loss: 2.3102 - accuracy: 0.0988 - val_loss: 2.3027 - val_accuracy: 0.0980
# Epoch 3/100
# 100/100 [==============================] - 4s 39ms/step - loss: 2.7563 - accuracy: 0.0989 - val_loss: 2.3027 - val_accuracy: 0.0980
# Epoch 4/100
# 100/100 [==============================] - 4s 39ms/step - loss: 2.5542 - accuracy: 0.1001 - val_loss: 2.3028 - val_accuracy: 0.0980
# Epoch 5/100
# 100/100 [==============================] - 4s 39ms/step - loss: 2.3788 - accuracy: 0.1038 - val_loss: 2.3026 - val_accuracy: 0.0979
# Epoch 6/100
# 100/100 [==============================] - 4s 39ms/step - loss: 2.4193 - accuracy: 0.1018 - val_loss: 2.3022 - val_accuracy: 0.1000
# Epoch 7/100
# 100/100 [==============================] - 4s 42ms/step - loss: 6.9354 - accuracy: 0.1079 - val_loss: 2.2000 - val_accuracy: 0.1684
# Epoch 8/100
# 100/100 [==============================] - 4s 39ms/step - loss: 2.3042 - accuracy: 0.1287 - val_loss: 2.3033 - val_accuracy: 0.1014
# Epoch 9/100
# 100/100 [==============================] - 4s 40ms/step - loss: 2.3157 - accuracy: 0.1081 - val_loss: 4.1021 - val_accuracy: 0.1007
# Epoch 10/100
# 100/100 [==============================] - 4s 42ms/step - loss: 2.3913 - accuracy: 0.1244 - val_loss: 2.2406 - val_accuracy: 0.1139
# Epoch 11/100
# 100/100 [==============================] - 4s 41ms/step - loss: 2.2582 - accuracy: 0.1469 - val_loss: 2.0300 - val_accuracy: 0.1765
# Epoch 12/100
# 100/100 [==============================] - 4s 42ms/step - loss: 2.0433 - accuracy: 0.1794 - val_loss: 2.0959 - val_accuracy: 0.1682
# Epoch 13/100
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3403 - accuracy: 0.9028 - val_loss: 1.5629 - val_accuracy: 0.7374
# Epoch 51/100
# 100/100 [==============================] - 6s 64ms/step - loss: 0.3606 - accuracy: 0.9013 - val_loss: 1.2354 - val_accuracy: 0.7580
# Epoch 52/100
# 100/100 [==============================] - 4s 44ms/step - loss: 0.3390 - accuracy: 0.9129 - val_loss: 1.0904 - val_accuracy: 0.7501
# Epoch 53/100
# 100/100 [==============================] - 4s 43ms/step - loss: 0.3140 - accuracy: 0.9213 - val_loss: 1.0404 - val_accuracy: 0.7524
# Epoch 54/100
# 100/100 [==============================] - 4s 41ms/step - loss: 0.2828 - accuracy: 0.9209 - val_loss: 1.7097 - val_accuracy: 0.7714
# Epoch 55/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3015 - accuracy: 0.9161 - val_loss: 1.1375 - val_accuracy: 0.7520
# Epoch 56/100
# 100/100 [==============================] - 4s 44ms/step - loss: 0.2556 - accuracy: 0.9281 - val_loss: 1.7285 - val_accuracy: 0.7666
# Epoch 57/100
# 100/100 [==============================] - 4s 43ms/step - loss: 0.2818 - accuracy: 0.9301 - val_loss: 1.1612 - val_accuracy: 0.7213
# Epoch 58/100
# 100/100 [==============================] - 4s 42ms/step - loss: 0.2626 - accuracy: 0.9307 - val_loss: 1.7855 - val_accuracy: 0.7498
# Epoch 59/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3375 - accuracy: 0.9190 - val_loss: 1.2904 - val_accuracy: 0.7607
# Epoch 60/100
# 100/100 [==============================] - 4s 41ms/step - loss: 0.5831 - accuracy: 0.9163 - val_loss: 1.3237 - val_accuracy: 0.6844
# Epoch 61/100
# 100/100 [==============================] - 4s 41ms/step - loss: 0.2215 - accuracy: 0.9332 - val_loss: 2.0560 - val_accuracy: 0.7749
# Epoch 62/100
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3590 - accuracy: 0.9056 - val_loss: 1.4914 - val_accuracy: 0.7709
# Epoch 63/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2385 - accuracy: 0.9366 - val_loss: 1.7043 - val_accuracy: 0.7729
# Epoch 64/100
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3069 - accuracy: 0.9259 - val_loss: 1.3615 - val_accuracy: 0.7592
# Epoch 65/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2568 - accuracy: 0.9344 - val_loss: 1.2607 - val_accuracy: 0.7691
# Epoch 66/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2568 - accuracy: 0.9378 - val_loss: 1.3125 - val_accuracy: 0.6708
# Epoch 67/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2473 - accuracy: 0.9380 - val_loss: 2.4911 - val_accuracy: 0.7758
# Epoch 68/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2734 - accuracy: 0.9346 - val_loss: 3.0198 - val_accuracy: 0.7796
# Epoch 69/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.1931 - accuracy: 0.9497 - val_loss: 3.4505 - val_accuracy: 0.7572
# Epoch 70/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.4394 - accuracy: 0.8973 - val_loss: 1.4177 - val_accuracy: 0.5519
# Epoch 71/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2750 - accuracy: 0.9259 - val_loss: 2.0422 - val_accuracy: 0.7711
# Epoch 72/100
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2670 - accuracy: 0.9356 - val_loss: 1.8202 - val_accuracy: 0.7705
# Epoch 73/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2497 - accuracy: 0.9378 - val_loss: 2.5092 - val_accuracy: 0.7698
# Epoch 74/100
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2489 - accuracy: 0.9382 - val_loss: 1.4702 - val_accuracy: 0.6848
# Epoch 75/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2299 - accuracy: 0.9431 - val_loss: 2.7419 - val_accuracy: 0.7605
# Epoch 76/100
# 100/100 [==============================] - 4s 40ms/step - loss: 0.3324 - accuracy: 0.9196 - val_loss: 1.9834 - val_accuracy: 0.6935
# Epoch 77/100
# 100/100 [==============================] - 5s 45ms/step - loss: 0.2781 - accuracy: 0.9338 - val_loss: 1.3581 - val_accuracy: 0.5922
# Epoch 78/100
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2161 - accuracy: 0.9433 - val_loss: 1.7632 - val_accuracy: 0.7561
# Epoch 79/100
# 100/100 [==============================] - 4s 40ms/step - loss: 0.2357 - accuracy: 0.9413 - val_loss: 3.1320 - val_accuracy: 0.7603
# Epoch 80/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2876 - accuracy: 0.9327 - val_loss: 4.3252 - val_accuracy: 0.7471
# Epoch 81/100
# 100/100 [==============================] - 4s 39ms/step - loss: 2.2405 - accuracy: 0.9111 - val_loss: 1.4594 - val_accuracy: 0.7489
# Epoch 82/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.1824 - accuracy: 0.9525 - val_loss: 1.9372 - val_accuracy: 0.7812
# Epoch 83/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3783 - accuracy: 0.9144 - val_loss: 1.8829 - val_accuracy: 0.7723
# Epoch 84/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2351 - accuracy: 0.9443 - val_loss: 2.0529 - val_accuracy: 0.7393
# Epoch 85/100
# 100/100 [==============================] - 4s 39ms/step - loss: 28.2309 - accuracy: 0.8977 - val_loss: 1.4213 - val_accuracy: 0.7641
# Epoch 86/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.1244 - accuracy: 0.9678 - val_loss: 2.6169 - val_accuracy: 0.7868
# Epoch 87/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2715 - accuracy: 0.9339 - val_loss: 2.7911 - val_accuracy: 0.7788
# Epoch 88/100
# 100/100 [==============================] - 4s 39ms/step - loss: 1.1662 - accuracy: 0.9136 - val_loss: 1.4824 - val_accuracy: 0.5401
# Epoch 89/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3602 - accuracy: 0.8932 - val_loss: 3.7473 - val_accuracy: 0.7621
# Epoch 90/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3705 - accuracy: 0.9318 - val_loss: 2.7758 - val_accuracy: 0.7736
# Epoch 91/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.6558 - accuracy: 0.9227 - val_loss: 1.2528 - val_accuracy: 0.7325
# Epoch 92/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2145 - accuracy: 0.9477 - val_loss: 1.5945 - val_accuracy: 0.7789
# Epoch 93/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.4195 - accuracy: 0.9215 - val_loss: 1.8411 - val_accuracy: 0.7666
# Epoch 94/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2565 - accuracy: 0.9478 - val_loss: 2.0720 - val_accuracy: 0.7819
# Epoch 95/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2488 - accuracy: 0.9362 - val_loss: 3.7856 - val_accuracy: 0.7641
# Epoch 96/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3206 - accuracy: 0.9271 - val_loss: 1.7349 - val_accuracy: 0.7663
# Epoch 97/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2912 - accuracy: 0.9341 - val_loss: 2.7607 - val_accuracy: 0.7312
# Epoch 98/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2476 - accuracy: 0.9417 - val_loss: 5.0488 - val_accuracy: 0.7821
# Epoch 99/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.4225 - accuracy: 0.9176 - val_loss: 48.0476 - val_accuracy: 0.6668
# Epoch 100/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.3705 - accuracy: 0.9217 - val_loss: 2.0355 - val_accuracy: 0.7824
# 1563/1563 [==============================] - 34s 20ms/step - loss: 0.4435 - accuracy: 0.9481
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-46d24abc0754> in <module>
#      23                   validation_split=0.2, verbose=1)
#      24   train_loss, train_acc = model.evaluate(x_train, y_train, verbose=1)
# ---> 25   test_loss, test_acc = model.evaluate(x_test, y_test, verbose=1)
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in tf__test_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 1557, in test_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 1546, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#
#     ValueError: input tensor Tensor("cond/Identity_8:0", dtype=float32) to TPUStrategy.run() has unknown rank, which is not allowed
